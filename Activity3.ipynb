# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel('Telco-Customer-Churn.xlsx')

# %%
data.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# # 1) Compare churn count with respect to gender.

# %%
from statsmodels.graphics.mosaicplot import mosaic
mosaic(df, ['gender', 'Churn'],title='Churn count with respect to gender')
# Out:
# (<Figure size 432x288 with 3 Axes>,
#  {('Female', 'No'): (0.0, 0.0, 0.4927796061577672, 0.7283634063823949),
#   ('Female', 'Yes'): (0.0,
#    0.7316856655186076,
#    0.4927796061577672,
#    0.2683143344813923),
#   ('Male', 'No'): (0.49775473053587665,
#    0.0,
#    0.5022452694641234,
#    0.7359434795407712),
#   ('Male', 'Yes'): (0.49775473053587665,
#    0.7392657386769838,
#    0.5022452694641234,
#    0.26073426132301614)})

# %%
sns.countplot(data=df,x='gender',hue='Churn')
plt.title('Churn count with respect to gender')
plt.xlabel('Gender')
plt.show()

# %% [markdown]
# # 2) Findout how many female senior citizen there in the dataset

# %%
df1=pd.DataFrame(data,columns=['gender','SeniorCitizen'])

# %%
df1.groupby(['gender']).sum()
# Out:
#         SeniorCitizen
# gender
# Female            568
# Male              574

# %% [markdown]
# # 3) Compare 'tenure' with 'Total Charges'

# %%
df2=pd.DataFrame(data,columns=['tenure','TotalCharges'])

# %%
df2
# Out:
#       tenure TotalCharges
# 0          1        29.85
# 1         34       1889.5
# 2          2       108.15
# 3         45      1840.75
# 4          2       151.65
# ...      ...          ...
# 7038      24       1990.5
# 7039      72       7362.9
# 7040      11       346.45
# 7041       4        306.6
# 7042      66       6844.5
#
# [7043 rows x 2 columns]

# %%
df2['TotalCharges']=pd.to_numeric(df2['TotalCharges'],errors='coerce')
df2['tenure']=pd.to_numeric(df2['tenure'],errors='coerce')
x=df2['tenure']
y=df2['TotalCharges']
plt.figure(figsize=(10,10))
plt.bar(x,y)
plt.title('Tenure v/s Total charges',fontsize=15)
plt.xlabel('Tenure',fontsize=12)
plt.ylabel('Total Charges',fontsize=12)
plt.show()

# %% [markdown]
# # 4) Find out which contracts are preferred by the senior citizen.

# %%
df3=pd.DataFrame(data,columns=['Contract','SeniorCitizen'])

# %%
df3.groupby(['Contract']).sum()
# Out:
#                 SeniorCitizen
# Contract
# Month-to-month            807
# One year                  190
# Two year                  145

# %%
print('The contract preferred by most of the senior citizens is Month-to-month')
# Out:
# The contract preferred by most of the senior citizens is Month-to-month

# %% [markdown]
# # 5) Comment your finds on Payment Method.

# %%
df['PaymentMethod'].value_counts()
# Out:
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: PaymentMethod, dtype: int64

# %%
sns.countplot(data=df,x='Contract',hue='PaymentMethod')
plt.title('Payment method on the basis of contracts')
plt.xlabel('Contract',fontsize=12)
plt.show()

# %%
sns.countplot(data=df,x='PaperlessBilling',hue='PaymentMethod')
plt.title('Payment method on the Billing')
plt.xlabel('Paperless Billing')
plt.show()

# %%
print('There are 4 types of payment methods.The number of people using each kind of method is-\n1.Electronic check-2365 \n2.Mailed check-1612\n3.Bank Transfer-1544\n4.Credit card-1522')
# Out:
# There are 4 types of payment methods.The number of people using each kind of method is-
# 1.Electronic check-2365
# 2.Mailed check-1612
# 3.Bank Transfer-1544
# 4.Credit card-1522
